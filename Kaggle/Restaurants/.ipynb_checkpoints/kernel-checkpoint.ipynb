# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (15,7)

# %%
df = pd.read_csv('datasets/sample_submission.csv', sep=',')

# %%
df_ids = pd.read_csv('datasets/store_id_relation.csv', sep=',')
df_date_info = pd.read_csv('datasets/date_info.csv', sep=',')
df_air_visits = pd.read_csv('datasets/air_visit_data.csv', sep=',')
df_air_info = pd.read_csv('datasets/air_store_info.csv', sep=',')
df_hpg_info = pd.read_csv('datasets/hpg_store_info.csv', sep=',')

df_hpg_reserve = pd.read_csv('datasets/hpg_reserve.csv', sep=',')
df_air_reserve = pd.read_csv('datasets/air_reserve.csv', sep=',')

# %%
TEST_START_DATE = dt.date(2017, 4, 3)
TEST_END_DATE = dt.date(2017, 5, 1)

# %%
df_date_info.calendar_date = pd.to_datetime(df_date_info.calendar_date)
df_date_info.holiday_flg = df_date_info.holiday_flg.astype('bool')
df_date_info.head()
# Out:
#   calendar_date day_of_week  holiday_flg
# 0    2016-01-01      Friday         True
# 1    2016-01-02    Saturday         True
# 2    2016-01-03      Sunday         True
# 3    2016-01-04      Monday        False
# 4    2016-01-05     Tuesday        False

# %%
df_air_visits.visit_date = pd.to_datetime(df_air_visits.visit_date)
df_air_visits.head()
# Out:
#            air_store_id visit_date  visitors
# 0  air_ba937bf13d40fb24 2016-01-13        25
# 1  air_ba937bf13d40fb24 2016-01-14        32
# 2  air_ba937bf13d40fb24 2016-01-15        29
# 3  air_ba937bf13d40fb24 2016-01-16        22
# 4  air_ba937bf13d40fb24 2016-01-18         6

# %%
dates_ids_index = pd.MultiIndex.from_product(
    [df_date_info.calendar_date, df_air_visits.air_store_id.unique()], names = ["calendar_date", "air_store_id"]
)

dates_ids_df = pd.DataFrame(index = dates_ids_index).reset_index()
dates_ids_df = dates_ids_df.merge(
    df_date_info,
    on='calendar_date',
    how='inner'
)
dates_ids_df.calendar_date = pd.to_datetime(dates_ids_df.calendar_date)

# %%
# dates_ids_df.tail()
# df_date_info.calendar_date.describe() # 517
# len(df_air_visits.air_store_id.unique()) # 829
# Out:
# 829

# %%
df_hpg_reserve = df_ids.merge(
    df_hpg_reserve, on='hpg_store_id', how='left'
).drop(columns='hpg_store_id')

# %%
df_hpg_reserve.head()
# Out:
#            air_store_id       visit_datetime     reserve_datetime  \
# 0  air_63b13c56b7201bd9  2016-01-04 12:00:00  2016-01-03 14:00:00
# 1  air_63b13c56b7201bd9  2016-01-04 14:00:00  2016-01-02 13:00:00
# 2  air_63b13c56b7201bd9  2016-01-05 12:00:00  2016-01-01 08:00:00
# 3  air_63b13c56b7201bd9  2016-01-09 12:00:00  2016-01-07 20:00:00
# 4  air_63b13c56b7201bd9  2016-01-11 12:00:00  2016-01-10 15:00:00
#
#    reserve_visitors
# 0                 7
# 1                 4
# 2                 3
# 3                 6
# 4                 3

# %%
df_air_reserve.visit_datetime = pd.to_datetime(df_air_reserve.visit_datetime)
df_air_reserve.reserve_datetime = pd.to_datetime(df_air_reserve.reserve_datetime)

df_hpg_reserve.visit_datetime = pd.to_datetime(df_hpg_reserve.visit_datetime)
df_hpg_reserve.reserve_datetime = pd.to_datetime(df_hpg_reserve.reserve_datetime)

# %%
df_air_reserve.reserve_visitors.hist(bins=50, alpha = 0.5, normed=1)
df_hpg_reserve.reserve_visitors.hist(bins=50, alpha = 0.5, normed=1)

# %%
df_hpg_reserve.describe()
# Out:
#        reserve_visitors
# count      28183.000000
# mean           4.364120
# std            4.689755
# min            1.000000
# 25%            2.000000
# 50%            3.000000
# 75%            5.000000
# max          100.000000

# %%
df_hpg_reserve.quantile(0.9)
# Out:
# reserve_visitors    8.0
# Name: 0.9, dtype: float64

# %%
df_air_reserve.describe()
# Out:
#        reserve_visitors
# count      92378.000000
# mean           4.481749
# std            4.919669
# min            1.000000
# 25%            2.000000
# 50%            3.000000
# 75%            5.000000
# max          100.000000

# %%
df_air_reserve.quantile(0.9)
# Out:
# reserve_visitors    8.0
# Name: 0.9, dtype: float64

# %%
df_hpg_reserve.tail(5)
# Out:
#                air_store_id      visit_datetime    reserve_datetime  \
# 28178  air_465bddfed3353b23 2017-04-10 19:00:00 2017-03-23 20:00:00
# 28179  air_465bddfed3353b23 2017-04-21 12:00:00 2017-04-17 16:00:00
# 28180  air_465bddfed3353b23 2017-04-27 18:00:00 2017-04-18 09:00:00
# 28181  air_465bddfed3353b23 2017-04-28 19:00:00 2017-04-19 13:00:00
# 28182  air_465bddfed3353b23 2017-05-02 19:00:00 2017-04-12 21:00:00
#
#        reserve_visitors
# 28178                23
# 28179                 8
# 28180                 4
# 28181                15
# 28182                 2

# %%
avg_air_bw_df = df_air_reserve.copy()
avg_air_bw_df['visit_date'] = pd.to_datetime(avg_air_bw_df.visit_datetime.dt.date)
avg_air_bw_df['booking_window'] = (avg_air_bw_df.visit_datetime - avg_air_bw_df.reserve_datetime).dt.seconds/3600
avg_air_bw_df.columns
avg_air_bw_df = avg_air_bw_df.groupby(['air_store_id', 'visit_date']).agg(
    {'reserve_visitors': 'mean', 
     'booking_window': 'median',
     'visit_datetime': 'count',
    })
avg_air_bw_df = avg_air_bw_df.rename(index=str, columns={"visit_datetime": "book_count"})
avg_air_bw_df['book_count'] = avg_air_bw_df.book_count.astype('int')

# %%
avg_hpg_bw_df = df_hpg_reserve.copy()
avg_hpg_bw_df['visit_date'] = pd.to_datetime(avg_hpg_bw_df.visit_datetime.dt.date)
avg_hpg_bw_df['booking_window'] = (avg_hpg_bw_df.visit_datetime - avg_hpg_bw_df.reserve_datetime).dt.seconds/3600
avg_hpg_bw_df.columns
avg_hpg_bw_df = avg_hpg_bw_df.groupby(['air_store_id', 'visit_date']).agg(
    {'reserve_visitors': 'mean', 
     'booking_window': 'median',
     'visit_datetime': 'count',
    })
avg_hpg_bw_df = avg_hpg_bw_df.rename(index=str, columns={"visit_datetime": "book_count"})
avg_hpg_bw_df.book_count = avg_hpg_bw_df.book_count.astype('int')

# %%
avg_air_bw_df.head(50)
# Out:
#                                           reserve_visitors  booking_window  \
# air_store_id         visit_date
# air_00a91d42b08b08d9 2016-10-31 00:00:00          2.000000             4.0
#                      2016-12-05 00:00:00          9.000000             4.0
#                      2016-12-14 00:00:00         18.000000             9.0
#                      2016-12-17 00:00:00          2.000000             3.0
#                      2016-12-20 00:00:00          4.000000             3.0
#                      2017-02-18 00:00:00          9.000000            17.0
#                      2017-02-23 00:00:00         12.000000            23.0
#                      2017-03-01 00:00:00          3.000000            17.0
#                      2017-03-14 00:00:00          4.000000             4.0
#                      2017-03-21 00:00:00          3.000000             4.0
#                      2017-03-24 00:00:00          2.000000             5.0
#                      2017-04-04 00:00:00          2.000000             4.0
# air_0164b9927d20bcc3 2016-10-28 00:00:00          6.000000             1.5
#                      2016-11-01 00:00:00          5.000000            12.5
#                      2016-11-02 00:00:00          3.000000             4.0
#                      2016-11-08 00:00:00          9.000000             0.0
#                      2016-11-10 00:00:00          3.000000            12.5
#                      2016-11-11 00:00:00          2.000000            13.0
#                      2016-11-14 00:00:00          5.666667             9.0
#                      2016-11-15 00:00:00          3.000000            22.0
#                      2016-11-16 00:00:00          2.000000             2.0
#                      2016-11-18 00:00:00          6.500000            11.0
#                      2016-11-21 00:00:00          3.000000             6.0
#                      2016-11-22 00:00:00          4.500000            13.0
#                      2016-11-24 00:00:00          2.000000             2.0
#                      2016-11-26 00:00:00         10.000000             7.0
#                      2016-11-28 00:00:00          2.000000            20.0
#                      2016-12-02 00:00:00          3.000000            21.0
#                      2016-12-05 00:00:00          2.000000             3.0
#                      2016-12-06 00:00:00          2.000000             2.0
#                      2016-12-07 00:00:00          2.000000            20.0
#                      2016-12-08 00:00:00          3.000000             3.0
#                      2016-12-14 00:00:00          2.000000            20.0
#                      2016-12-15 00:00:00          5.000000             5.0
#                      2016-12-16 00:00:00          2.000000            22.0
#                      2016-12-19 00:00:00          2.000000            11.0
#                      2016-12-21 00:00:00          2.000000             5.0
#                      2016-12-22 00:00:00          3.500000             6.5
#                      2016-12-23 00:00:00          2.000000            22.0
#                      2016-12-26 00:00:00          2.000000             8.0
#                      2016-12-27 00:00:00          3.000000            22.0
#                      2017-01-06 00:00:00          3.000000             1.0
#                      2017-01-12 00:00:00          5.000000            16.5
#                      2017-01-13 00:00:00          2.000000            17.0
#                      2017-01-14 00:00:00          9.000000            23.0
#                      2017-01-16 00:00:00          3.000000             3.0
#                      2017-01-17 00:00:00          3.000000             5.5
#                      2017-01-19 00:00:00          2.000000             1.0
#                      2017-01-20 00:00:00          2.000000             8.0
#                      2017-01-23 00:00:00          1.833333             9.5
#
#                                           book_count
# air_store_id         visit_date
# air_00a91d42b08b08d9 2016-10-31 00:00:00           1
#                      2016-12-05 00:00:00           1
#                      2016-12-14 00:00:00           1
#                      2016-12-17 00:00:00           1
#                      2016-12-20 00:00:00           1
#                      2017-02-18 00:00:00           1
#                      2017-02-23 00:00:00           1
#                      2017-03-01 00:00:00           1
#                      2017-03-14 00:00:00           1
#                      2017-03-21 00:00:00           1
#                      2017-03-24 00:00:00           1
#                      2017-04-04 00:00:00           1
# air_0164b9927d20bcc3 2016-10-28 00:00:00           2
#                      2016-11-01 00:00:00           2
#                      2016-11-02 00:00:00           1
#                      2016-11-08 00:00:00           1
#                      2016-11-10 00:00:00           2
#                      2016-11-11 00:00:00           2
#                      2016-11-14 00:00:00           3
#                      2016-11-15 00:00:00           1
#                      2016-11-16 00:00:00           1
#                      2016-11-18 00:00:00           2
#                      2016-11-21 00:00:00           1
#                      2016-11-22 00:00:00           2
#                      2016-11-24 00:00:00           1
#                      2016-11-26 00:00:00           1
#                      2016-11-28 00:00:00           1
#                      2016-12-02 00:00:00           1
#                      2016-12-05 00:00:00           2
#                      2016-12-06 00:00:00           1
#                      2016-12-07 00:00:00           1
#                      2016-12-08 00:00:00           3
#                      2016-12-14 00:00:00           1
#                      2016-12-15 00:00:00           3
#                      2016-12-16 00:00:00           3
#                      2016-12-19 00:00:00           1
#                      2016-12-21 00:00:00           1
#                      2016-12-22 00:00:00           2
#                      2016-12-23 00:00:00           1
#                      2016-12-26 00:00:00           1
#                      2016-12-27 00:00:00           1
#                      2017-01-06 00:00:00           1
#                      2017-01-12 00:00:00           2
#                      2017-01-13 00:00:00           1
#                      2017-01-14 00:00:00           1
#                      2017-01-16 00:00:00           2
#                      2017-01-17 00:00:00           2
#                      2017-01-19 00:00:00           1
#                      2017-01-20 00:00:00           1
#                      2017-01-23 00:00:00           6

# %%
avg_bw_df = avg_air_bw_df.reset_index().merge(
    avg_hpg_bw_df.reset_index(),
    how='outer',
    on=['air_store_id', 'visit_date'],
    suffixes=['_air', '_hpg'],
).fillna(0)
avg_bw_df.visit_date = pd.to_datetime(avg_bw_df.visit_date)

# %%
visits_and_dates_df = df_air_visits.merge(
    dates_ids_df,
    left_on=['visit_date', 'air_store_id'],
    right_on=['calendar_date', 'air_store_id'],
    how='outer',
).drop(columns='visit_date')

# %%
visits_and_dates_df
# Out:
#                 air_store_id  visitors calendar_date day_of_week  holiday_flg
# 0       air_ba937bf13d40fb24      25.0    2016-01-13   Wednesday        False
# 1       air_ba937bf13d40fb24      32.0    2016-01-14    Thursday        False
# 2       air_ba937bf13d40fb24      29.0    2016-01-15      Friday        False
# 3       air_ba937bf13d40fb24      22.0    2016-01-16    Saturday        False
# 4       air_ba937bf13d40fb24       6.0    2016-01-18      Monday        False
# 5       air_ba937bf13d40fb24       9.0    2016-01-19     Tuesday        False
# 6       air_ba937bf13d40fb24      31.0    2016-01-20   Wednesday        False
# 7       air_ba937bf13d40fb24      21.0    2016-01-21    Thursday        False
# 8       air_ba937bf13d40fb24      18.0    2016-01-22      Friday        False
# 9       air_ba937bf13d40fb24      26.0    2016-01-23    Saturday        False
# 10      air_ba937bf13d40fb24      21.0    2016-01-25      Monday        False
# 11      air_ba937bf13d40fb24      11.0    2016-01-26     Tuesday        False
# 12      air_ba937bf13d40fb24      24.0    2016-01-27   Wednesday        False
# 13      air_ba937bf13d40fb24      21.0    2016-01-28    Thursday        False
# 14      air_ba937bf13d40fb24      26.0    2016-01-29      Friday        False
# 15      air_ba937bf13d40fb24       6.0    2016-01-30    Saturday        False
# 16      air_ba937bf13d40fb24      18.0    2016-02-03   Wednesday        False
# 17      air_ba937bf13d40fb24      12.0    2016-02-04    Thursday        False
# 18      air_ba937bf13d40fb24      45.0    2016-02-05      Friday        False
# 19      air_ba937bf13d40fb24      15.0    2016-02-06    Saturday        False
# 20      air_ba937bf13d40fb24      19.0    2016-02-08      Monday        False
# 21      air_ba937bf13d40fb24      15.0    2016-02-09     Tuesday        False
# 22      air_ba937bf13d40fb24      32.0    2016-02-10   Wednesday        False
# 23      air_ba937bf13d40fb24       3.0    2016-02-11    Thursday         True
# 24      air_ba937bf13d40fb24      26.0    2016-02-12      Friday        False
# 25      air_ba937bf13d40fb24       8.0    2016-02-13    Saturday        False
# 26      air_ba937bf13d40fb24      14.0    2016-02-15      Monday        False
# 27      air_ba937bf13d40fb24      15.0    2016-02-16     Tuesday        False
# 28      air_ba937bf13d40fb24      17.0    2016-02-17   Wednesday        False
# 29      air_ba937bf13d40fb24      22.0    2016-02-18    Thursday        False
# ...                      ...       ...           ...         ...          ...
# 428563  air_57c9eea1a2b66e65       NaN    2017-05-31   Wednesday        False
# 428564  air_d6b3e67261f07646       NaN    2017-05-31   Wednesday        False
# 428565  air_ea7c16131980c837       NaN    2017-05-31   Wednesday        False
# 428566  air_3d3a2b509180e798       NaN    2017-05-31   Wednesday        False
# 428567  air_4b380b4db9d37883       NaN    2017-05-31   Wednesday        False
# 428568  air_4b55d8aea1d2b395       NaN    2017-05-31   Wednesday        False
# 428569  air_640cf4835f0d9ba3       NaN    2017-05-31   Wednesday        False
# 428570  air_0328696196e46f18       NaN    2017-05-31   Wednesday        False
# 428571  air_15e6e15c7ea2c162       NaN    2017-05-31   Wednesday        False
# 428572  air_dad0b6a36138f309       NaN    2017-05-31   Wednesday        False
# 428573  air_f068442ebb6c246c       NaN    2017-05-31   Wednesday        False
# 428574  air_49211568cab5fdee       NaN    2017-05-31   Wednesday        False
# 428575  air_506fe758114df773       NaN    2017-05-31   Wednesday        False
# 428576  air_1d1e8860ae04f8e9       NaN    2017-05-31   Wednesday        False
# 428577  air_a510dcfe979f09eb       NaN    2017-05-31   Wednesday        False
# 428578  air_0e1eae99b8723bc1       NaN    2017-05-31   Wednesday        False
# 428579  air_2d78d9a1f4dd02ca       NaN    2017-05-31   Wednesday        False
# 428580  air_7d65049f9d275c0d       NaN    2017-05-31   Wednesday        False
# 428581  air_bfafaed35e213fd7       NaN    2017-05-31   Wednesday        False
# 428582  air_754ae581ad80cc9f       NaN    2017-05-31   Wednesday        False
# 428583  air_e9ebf7fc520ac76a       NaN    2017-05-31   Wednesday        False
# 428584  air_7bc6ca04d7b0f3b8       NaN    2017-05-31   Wednesday        False
# 428585  air_084d98859256acf0       NaN    2017-05-31   Wednesday        False
# 428586  air_b5598d12d1b84890       NaN    2017-05-31   Wednesday        False
# 428587  air_31c753b48a657b6c       NaN    2017-05-31   Wednesday        False
# 428588  air_168441ada3e878e1       NaN    2017-05-31   Wednesday        False
# 428589  air_6c952e3c6e590945       NaN    2017-05-31   Wednesday        False
# 428590  air_0f2f96335f274801       NaN    2017-05-31   Wednesday        False
# 428591  air_c7d30ab0e07f31d5       NaN    2017-05-31   Wednesday        False
# 428592  air_24e8414b9b07decb       NaN    2017-05-31   Wednesday        False
#
# [428593 rows x 5 columns]

# %%
bw_and_visits_df = avg_bw_df.merge(
    visits_and_dates_df,
    left_on=['visit_date', 'air_store_id'],
    right_on=['calendar_date', 'air_store_id'],
    how='outer',
).drop(columns='visit_date')

# %%
bw_and_visits_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 428593 entries, 0 to 428592
# Data columns (total 11 columns):
# air_store_id            428593 non-null object
# reserve_visitors_air    42193 non-null float64
# booking_window_air      42193 non-null float64
# book_count_air          42193 non-null float64
# reserve_visitors_hpg    42193 non-null float64
# booking_window_hpg      42193 non-null float64
# book_count_hpg          42193 non-null float64
# visitors                252108 non-null float64
# calendar_date           428593 non-null datetime64[ns]
# day_of_week             428593 non-null object
# holiday_flg             428593 non-null bool
# dtypes: bool(1), datetime64[ns](1), float64(7), object(2)
# memory usage: 36.4+ MB

# %%
restaurants_df = df_ids.merge(df_air_info, on='air_store_id', how='outer')
len(restaurants_df)
# Out:
# 829

# %%
restaurants_df = restaurants_df.merge(
    df_hpg_info,
    on='hpg_store_id',
    how='left'
)
len(restaurants_df)
# Out:
# 829

# %%
def mean_coord(xs, ys):
    res = []
    for x, y in zip(xs, ys):
        if not np.isnan(x) and not np.isnan(y):
            res.append((x+y)/2)
        elif np.isnan(x):
            res.append(y)
        else:
            res.append(x)
    return res

# %%
restaurants_df['mean_latitude'] = mean_coord(restaurants_df.latitude_y, restaurants_df.latitude_x)
restaurants_df['mean_longitude'] = mean_coord(restaurants_df.longitude_y, restaurants_df.longitude_x)

# %%
restaurants_df.head()
# Out:
#            air_store_id          hpg_store_id                air_genre_name  \
# 0  air_63b13c56b7201bd9  hpg_4bc649e72e2a239a                   Cafe/Sweets
# 1  air_a24bf50c3e90d583  hpg_c34b496d0305a809                    Dining bar
# 2  air_c7f78b4f3cba33ff  hpg_cd8ae0d9bbd58ff9  Okonomiyaki/Monja/Teppanyaki
# 3  air_947eb2cae4f3e8f2  hpg_de24ea49dc25d6b8                       Izakaya
# 4  air_965b2e0cf4119003  hpg_653238a84804d8e7                       Izakaya
#
#                              air_area_name  latitude_x  longitude_x  \
# 0           Fukuoka-ken Fukuoka-shi Daimyō   33.586994   130.394894
# 1  Shizuoka-ken Hamamatsu-shi Motoshirochō   34.710895   137.725940
# 2             Tōkyō-to Minato-ku Shibakōen   35.658068   139.751599
# 3    Fukuoka-ken Fukuoka-shi Hakata Ekimae   33.591358   130.414878
# 4            Tōkyō-to Meguro-ku Kamimeguro   35.641463   139.698171
#
#   hpg_genre_name                           hpg_area_name  latitude_y  \
# 0            NaN                                     NaN         NaN
# 1        Italian  Shizuoka-ken Hamamatsu-shi Sukenobuchō   34.721644
# 2            NaN                                     NaN         NaN
# 3            NaN                                     NaN         NaN
# 4            NaN                                     NaN         NaN
#
#    longitude_y  mean_latitude  mean_longitude
# 0          NaN      33.586994      130.394894
# 1   137.738944      34.716270      137.732442
# 2          NaN      35.658068      139.751599
# 3          NaN      33.591358      130.414878
# 4          NaN      35.641463      139.698171

# %%
restaurants_df = restaurants_df.drop(
    columns=['latitude_y', 'latitude_x', 'longitude_x', 'longitude_y', 'hpg_store_id']
)

# %%
restaurants_df.tail()
# Out:
#              air_store_id         air_genre_name  \
# 824  air_6b65745d432fd77f  International cuisine
# 825  air_9bf595ef095572fb  International cuisine
# 826  air_764f71040a413d4d                  Asian
# 827  air_10bbe8acd943d8f6                  Asian
# 828  air_c8fe396d6c46275d          Karaoke/Party
#
#                              air_area_name hpg_genre_name hpg_area_name  \
# 824            Tōkyō-to Shibuya-ku Shibuya            NaN           NaN
# 825            Tōkyō-to Shibuya-ku Shibuya            NaN           NaN
# 826            Tōkyō-to Shibuya-ku Shibuya            NaN           NaN
# 827            Tōkyō-to Shibuya-ku Shibuya            NaN           NaN
# 828  Hokkaidō Sapporo-shi Minami 3 Jōnishi            NaN           NaN
#
#      mean_latitude  mean_longitude
# 824      35.661777      139.704051
# 825      35.661777      139.704051
# 826      35.661777      139.704051
# 827      35.661777      139.704051
# 828      43.055460      141.340956

# %%
# restaurants_hash_df = restaurants_df.copy()
# restaurants_hash_df.air_genre_name = restaurants_hash_df.air_genre_name.map(hash)
# restaurants_hash_df.air_area_name = restaurants_hash_df.air_area_name.map(hash)
# restaurants_hash_df.hpg_genre_name = restaurants_hash_df.hpg_genre_name.map(hash)
# restaurants_hash_df.hpg_area_name = restaurants_hash_df.hpg_area_name.map(hash)

# %%
restaurants_df.groupby('air_genre_name').nunique()
# Out:
#                               air_store_id  air_genre_name  air_area_name  \
# air_genre_name
# Asian                                    2               1              1
# Bar/Cocktail                            79               1             22
# Cafe/Sweets                            181               1             46
# Creative cuisine                        13               1              6
# Dining bar                             108               1             31
# International cuisine                    2               1              1
# Italian/French                         102               1             24
# Izakaya                                197               1             56
# Japanese food                           63               1             22
# Karaoke/Party                            2               1              1
# Okonomiyaki/Monja/Teppanyaki            14               1              6
# Other                                   27               1             12
# Western food                            16               1              6
# Yakiniku/Korean food                    23               1             10
#
#                               hpg_genre_name  hpg_area_name  mean_latitude  \
# air_genre_name
# Asian                                      0              0              1
# Bar/Cocktail                               4              3             27
# Cafe/Sweets                                0              0             48
# Creative cuisine                           0              0              6
# Dining bar                                 5             11             42
# International cuisine                      0              0              1
# Italian/French                             2              4             28
# Izakaya                                    6             19             75
# Japanese food                              3              5             28
# Karaoke/Party                              1              1              2
# Okonomiyaki/Monja/Teppanyaki               1              1              7
# Other                                      0              0             12
# Western food                               1              1              7
# Yakiniku/Korean food                       2              4             14
#
#                               mean_longitude
# air_genre_name
# Asian                                      1
# Bar/Cocktail                              27
# Cafe/Sweets                               48
# Creative cuisine                           6
# Dining bar                                42
# International cuisine                      1
# Italian/French                            28
# Izakaya                                   75
# Japanese food                             28
# Karaoke/Party                              2
# Okonomiyaki/Monja/Teppanyaki               7
# Other                                     12
# Western food                               7
# Yakiniku/Korean food                      14

# %%
restaurants_df.groupby('hpg_genre_name').nunique()
# Out:
#                               air_store_id  air_genre_name  air_area_name  \
# hpg_genre_name
# Amusement bar                            1               1              1
# Cafe                                     1               1              1
# Creation                                 5               2              4
# Creative Japanese food                   1               1              1
# Grilled meat                             3               1              3
# International cuisine                   11               3             10
# Italian                                  5               2              4
# Japanese cuisine/Kaiseki                 1               1              1
# Japanese food in general                 1               1              1
# Japanese style                          20               3             15
# Karaoke                                  1               1              1
# Okonomiyaki/Monja/Teppanyaki             1               1              1
# Party                                    1               1              1
# Seafood                                  3               2              2
# Spain Bar/Italian Bar                    7               3              5
# Steak/Hamburger/Curry                    1               1              1
#
#                               hpg_genre_name  hpg_area_name  mean_latitude  \
# hpg_genre_name
# Amusement bar                              1              1              1
# Cafe                                       1              1              1
# Creation                                   1              4              4
# Creative Japanese food                     1              1              1
# Grilled meat                               1              3              3
# International cuisine                      1             10             10
# Italian                                    1              4              4
# Japanese cuisine/Kaiseki                   1              1              1
# Japanese food in general                   1              1              1
# Japanese style                             1             16             16
# Karaoke                                    1              1              1
# Okonomiyaki/Monja/Teppanyaki               1              1              1
# Party                                      1              1              1
# Seafood                                    1              2              2
# Spain Bar/Italian Bar                      1              7              7
# Steak/Hamburger/Curry                      1              1              1
#
#                               mean_longitude
# hpg_genre_name
# Amusement bar                              1
# Cafe                                       1
# Creation                                   4
# Creative Japanese food                     1
# Grilled meat                               3
# International cuisine                     10
# Italian                                    4
# Japanese cuisine/Kaiseki                   1
# Japanese food in general                   1
# Japanese style                            16
# Karaoke                                    1
# Okonomiyaki/Monja/Teppanyaki               1
# Party                                      1
# Seafood                                    2
# Spain Bar/Italian Bar                      7
# Steak/Hamburger/Curry                      1

# %%
len(restaurants_df[restaurants_df['hpg_genre_name'].isna()==False])
# Out:
# 63

# %%
restaraunts_and_dates_df = bw_and_visits_df.merge(
    restaurants_df,
    on='air_store_id',
    how='inner',
)

# %%
restaraunts_and_dates_df.head(10)
# Out:
#            air_store_id  reserve_visitors_air  booking_window_air  \
# 0  air_00a91d42b08b08d9                   2.0                 4.0
# 1  air_00a91d42b08b08d9                   9.0                 4.0
# 2  air_00a91d42b08b08d9                  18.0                 9.0
# 3  air_00a91d42b08b08d9                   2.0                 3.0
# 4  air_00a91d42b08b08d9                   4.0                 3.0
# 5  air_00a91d42b08b08d9                   9.0                17.0
# 6  air_00a91d42b08b08d9                  12.0                23.0
# 7  air_00a91d42b08b08d9                   3.0                17.0
# 8  air_00a91d42b08b08d9                   4.0                 4.0
# 9  air_00a91d42b08b08d9                   3.0                 4.0
#
#    book_count_air  reserve_visitors_hpg  booking_window_hpg  book_count_hpg  \
# 0             1.0                   2.0                 4.0             1.0
# 1             1.0                   1.0                22.0             1.0
# 2             1.0                   0.0                 0.0             0.0
# 3             1.0                   2.0                 1.0             1.0
# 4             1.0                   4.0                 2.0             1.0
# 5             1.0                   9.0                17.0             1.0
# 6             1.0                  12.0                23.0             1.0
# 7             1.0                   4.0                17.0             1.0
# 8             1.0                   2.0                 5.0             1.0
# 9             1.0                   3.0                23.0             1.0
#
#    visitors calendar_date day_of_week  holiday_flg  air_genre_name  \
# 0      26.0    2016-10-31      Monday        False  Italian/French
# 1      33.0    2016-12-05      Monday        False  Italian/French
# 2      30.0    2016-12-14   Wednesday        False  Italian/French
# 3      17.0    2016-12-17    Saturday        False  Italian/French
# 4      37.0    2016-12-20     Tuesday        False  Italian/French
# 5      18.0    2017-02-18    Saturday        False  Italian/French
# 6      40.0    2017-02-23    Thursday        False  Italian/French
# 7      17.0    2017-03-01   Wednesday        False  Italian/French
# 8      28.0    2017-03-14     Tuesday        False  Italian/French
# 9      28.0    2017-03-21     Tuesday        False  Italian/French
#
#                      air_area_name hpg_genre_name hpg_area_name  \
# 0  Tōkyō-to Chiyoda-ku Kudanminami            NaN           NaN
# 1  Tōkyō-to Chiyoda-ku Kudanminami            NaN           NaN
# 2  Tōkyō-to Chiyoda-ku Kudanminami            NaN           NaN
# 3  Tōkyō-to Chiyoda-ku Kudanminami            NaN           NaN
# 4  Tōkyō-to Chiyoda-ku Kudanminami            NaN           NaN
# 5  Tōkyō-to Chiyoda-ku Kudanminami            NaN           NaN
# 6  Tōkyō-to Chiyoda-ku Kudanminami            NaN           NaN
# 7  Tōkyō-to Chiyoda-ku Kudanminami            NaN           NaN
# 8  Tōkyō-to Chiyoda-ku Kudanminami            NaN           NaN
# 9  Tōkyō-to Chiyoda-ku Kudanminami            NaN           NaN
#
#    mean_latitude  mean_longitude
# 0      35.694003      139.753595
# 1      35.694003      139.753595
# 2      35.694003      139.753595
# 3      35.694003      139.753595
# 4      35.694003      139.753595
# 5      35.694003      139.753595
# 6      35.694003      139.753595
# 7      35.694003      139.753595
# 8      35.694003      139.753595
# 9      35.694003      139.753595

# %%
restaraunts_and_dates_df.calendar_date.describe()
# Out:
# count                  428593
# unique                    517
# top       2016-12-27 00:00:00
# freq                      829
# first     2016-01-01 00:00:00
# last      2017-05-31 00:00:00
# Name: calendar_date, dtype: object
